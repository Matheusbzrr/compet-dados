# %% [markdown]
# # Conhecendo Python
# ## Bem-vindo(a) ao estudo de linguagem Python

# %%
x = 1 
y = 2.57
print("x vale", x)
print("y vale", y)
# Out:
# x vale 1
# y vale 2.57

# %%
x+y
# Out:
# 3.57

# %% [markdown]
# ## Trabalhando com pandas

# %%
import numpy as np
import pandas as pd

s = pd.Series([3, 7, 5, np.nan, 6, 8, "oi"])
s
# Out:
# 0    3.0
# 1    7.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
s[s.isnull()]
# Out:
# 3   NaN
# dtype: float64

# %%
df = pd.DataFrame(
    np.random.randint(1,5 ,size=(6,4)),
    index="",
    columns=['A', "B","C", "D"]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df = pd.DataFrame(
#       2     np.random.randint(1,5 ,size=(6,4)),
#       3     index="",
#       4     columns=['A', "B","C", "D"]
#       5 )
#
# File c:\Users\Pos\Desktop\compet-datascience\.venv\Lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)    824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
# ...

# %%
df.describe(include="O")
# Out:
#    0  1  2  3
# 0  3  4  1  2
# 1  2  4  2  2
# 2  4  3  4  1
# 3  3  1  4  2
# 4  3  3  2  3
# 5  2  2  2  1

# %% [markdown]
# ## Conhecendo os tipos

# %%
teste = []
type(teste)
# Out:
# list

# %%
int(3.99)
# Out:
# 3
