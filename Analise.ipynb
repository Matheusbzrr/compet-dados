# %% [markdown]
# # INEP - Média de alunos por turma
#  ## Carregando conjunto de dados

# %%
import pandas as pd

atu= pd.read_excel('datasete/ATU_BRASIL_REGIOES_UFS_2024.xlsx', skiprows=8)

atu
# Out:
#                                           NU_ANO_CENSO           UNIDGEO  \
# 0                                                 2024            Brasil
# 1                                                 2024            Brasil
# 2                                                 2024            Brasil
# 3                                                 2024            Brasil
# 4                                                 2024            Brasil
# ..                                                 ...               ...
# 586                                               2024  Distrito Federal
# 587                                               2024  Distrito Federal
# 588                                                NaN               NaN
# 589         Fonte: Censo da Educação Básica 2024/INEP.               NaN
# 590  Notas: 1) - Inclusive turmas Unificadas.\n    ...               NaN
#
#     NO_CATEGORIA NO_DEPENDENCIA ED_INF_CAT_0 CRE_CAT_0 PRE_CAT_0 FUN_CAT_0  \
# 0          Total          Total         15.4      13.7      17.3      22.4
# 1         Urbana          Total         15.6      13.6      17.7      23.8
# 2          Rural          Total         14.3        14      14.5        16
# 3          Total        Federal         12.3        10      14.6        26
# 4         Urbana        Federal         12.6      10.3      14.7        26
# ..           ...            ...          ...       ...       ...       ...
# 586       Urbana        Pública           19      14.3        19      23.1
# 587        Rural        Pública         16.3       9.9      16.7      19.9
# 588          NaN            NaN          NaN       NaN       NaN       NaN
# 589          NaN            NaN          NaN       NaN       NaN       NaN
# 590          NaN            NaN          NaN       NaN       NaN       NaN
#
#     FUN_AI_CAT_0 FUN_AF_CAT_0  ... FUN_07_CAT_0 FUN_08_CAT_0 FUN_09_CAT_0  \
# 0           20.9         25.9  ...         26.1           26         25.9
# 1           21.7         27.1  ...         27.2         27.2         27.3
# 2           15.9         18.5  ...         18.9         18.3         17.8
# 3           22.1           28  ...         28.2         28.8         27.8
# 4           22.1           28  ...         28.2         28.8         27.8
# ..           ...          ...  ...          ...          ...          ...
# 586         20.6         27.4  ...           28         27.2         28.5
# 587         18.8         22.5  ...         23.7         21.3         22.8
# 588          NaN          NaN  ...          NaN          NaN          NaN
# 589          NaN          NaN  ...          NaN          NaN          NaN
# 590          NaN          NaN  ...          NaN          NaN          NaN
#
#     MULT_ETA_CAT_0 MED_CAT_0 MED_01_CAT_0 MED_02_CAT_0 MED_03_CAT_0  \
# 0             13.9      28.9         30.6         28.8         27.5
# 1             16.4      29.6         31.2         29.4         28.2
# 2             13.6        21         22.8         21.2         19.3
# 3               --      30.5         34.3           31         28.1
# 4               --      30.6         34.5         31.2         28.1
# ..             ...       ...          ...          ...          ...
# 586             18      28.8         28.4           29         29.1
# 587             20      22.3         22.7         22.6         21.5
# 588            NaN       NaN          NaN          NaN          NaN
# 589            NaN       NaN          NaN          NaN          NaN
# 590            NaN       NaN          NaN          NaN          NaN
#
#     MED_04_CAT_0 MED_NS_CAT_0
# 0           21.3         21.8
# 1           21.4         23.6
# 2           19.9         14.2
# 3           23.3         27.6
# 4             23         27.4
# ..           ...          ...
# 586           --            2
# 587           --           --
# 588          NaN          NaN
# 589          NaN          NaN
# 590          NaN          NaN
#
# [591 rows x 26 columns]

# %%
atu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NU_ANO_CENSO    590 non-null    object
#  1   UNIDGEO         588 non-null    object
#  2   NO_CATEGORIA    588 non-null    object
#  3   NO_DEPENDENCIA  588 non-null    object
#  4   ED_INF_CAT_0    588 non-null    object
#  5   CRE_CAT_0       588 non-null    object
#  6   PRE_CAT_0       588 non-null    object
#  7   FUN_CAT_0       588 non-null    object
#  8   FUN_AI_CAT_0    588 non-null    object
#  9   FUN_AF_CAT_0    588 non-null    object
#  10  FUN_01_CAT_0    588 non-null    object
#  11  FUN_02_CAT_0    588 non-null    object
#  12  FUN_03_CAT_0    588 non-null    object
#  13  FUN_04_CAT_0    588 non-null    object
#  14  FUN_05_CAT_0    588 non-null    object
#  15  FUN_06_CAT_0    588 non-null    object
#  16  FUN_07_CAT_0    588 non-null    object
#  17  FUN_08_CAT_0    588 non-null    object
#  18  FUN_09_CAT_0    588 non-null    object
#  19  MULT_ETA_CAT_0  588 non-null    object
#  20  MED_CAT_0       588 non-null    object
#  21  MED_01_CAT_0    588 non-null    object
#  22  MED_02_CAT_0    588 non-null    object
#  23  MED_03_CAT_0    588 non-null    object
#  24  MED_04_CAT_0    588 non-null    object
#  25  MED_NS_CAT_0    588 non-null    object
# dtypes: object(26)
# memory usage: 120.2+ KB

# %% [markdown]
# # Preparando os dados para analise

# %% [markdown]
# **Obs.:** Todas as colunas estão sendo identificadas como Object
#
# Antes de resolver esse problemas vamos selecionar as colunas Unidade Geográfica, Localização, Dependência Administrativa, Total Infantil, Total Fundamental e Total Médio para efetuar a análise

# %%
atu = atu.iloc[:,[1, 2, 3, 4, 7, 20]]
atu
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 atu = atu.iloc[:,[1, 2, 3, 4, 7, 20]]
#       2 atu
#
# File c:\Users\Pos\Desktop\compet-datascience\.venv\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\Pos\Desktop\compet-datascience\.venv\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File c:\Users\Pos\Desktop\compet-datascience\.venv\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     964 for i, k in enumerate(key):
#     965     try:
# --> 966         self._validate_key(k, i)
#     967     except ValueError as err:
#     968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#
# File c:\Users\Pos\Desktop\compet-datascience\.venv\Lib\site-packages\pandas\core\indexing.py:1612, in _iLocIndexer._validate_key(self, key, axis)
#    1610     # check that the key does not exceed the maximum size of the index
#    1611     if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 1612         raise IndexError("positional indexers are out-of-bounds")
#    1613 else:
#    1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %% [markdown]
# Dicionário:
#
# - UG = Unidade Geografica
# - LOC = Localização
# - DA = Dependência Administrativa
# - TI = Total Ensino Infantil
# - TF = Total Ensino Fundamental
# - TM = Ttotal Ensino Médio

# %%
colunas = ['UG','LOC', 'DA', 'TI', 'TF', 'TM']
atu.columns = colunas
atu
# Out:
#                    UG     LOC       DA    TI    TF    TM
# 0              Brasil   Total    Total  15.4  22.4  28.9
# 1              Brasil  Urbana    Total  15.6  23.8  29.6
# 2              Brasil   Rural    Total  14.3    16    21
# 3              Brasil   Total  Federal  12.3    26  30.5
# 4              Brasil  Urbana  Federal  12.6    26  30.6
# ..                ...     ...      ...   ...   ...   ...
# 586  Distrito Federal  Urbana  Pública    19  23.1  28.8
# 587  Distrito Federal   Rural  Pública  16.3  19.9  22.3
# 588               NaN     NaN      NaN   NaN   NaN   NaN
# 589               NaN     NaN      NaN   NaN   NaN   NaN
# 590               NaN     NaN      NaN   NaN   NaN   NaN
#
# [591 rows x 6 columns]

# %%
atu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UG      588 non-null    object
#  1   LOC     588 non-null    object
#  2   DA      588 non-null    object
#  3   TI      588 non-null    object
#  4   TF      588 non-null    object
#  5   TM      588 non-null    object
# dtypes: object(6)
# memory usage: 27.8+ KB

# %% [markdown]
# Vamos considerar que os valores ausentes não existem escolas para alunos serem matriculados, portanto, subistituiremos os dados vazios por 0

# %%
df = atu.replace('--', 0)
# Out:
# C:\Users\Pos\AppData\Local\Temp\ipykernel_13192\3170459046.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = atu.replace('--', 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   UG      588 non-null    object
#  1   LOC     588 non-null    object
#  2   DA      588 non-null    object
#  3   TI      588 non-null    float64
#  4   TF      588 non-null    float64
#  5   TM      588 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 27.8+ KB

# %%
df.groupby("UG")[["TI", "TF", "TM"]].median().round(2)
# Out:
#                         TI     TF     TM
# UG
# Acre                 14.20  20.80  22.40
# Alagoas              16.70  20.00  33.10
# Amapá                12.90  17.40  27.20
# Amazonas             12.90  21.20  26.50
# Bahia                13.95  20.95  27.90
# Brasil               14.35  22.40  28.45
# Ceará                14.95  20.10  31.30
# Centro-Oeste         15.30  23.50  27.75
# Distrito Federal     16.30  22.30  28.90
# Espírito Santo       13.50  22.10  29.75
# Goiás                12.95  24.05  26.50
# Maranhão             14.65  19.40  30.75
# Mato Grosso          13.70  18.45  25.00
# Mato Grosso do Sul   15.30  25.00  28.60
# Minas Gerais         13.30  20.80  27.95
# Nordeste             15.10  21.65  29.55
# Norte                15.00  21.15  27.45
# Paraná               12.70  22.40  27.35
# Paraíba              15.65  17.70  27.55
# Pará                 14.50  21.35  29.95
# Pernambuco           15.30  23.15  27.20
# Piauí                14.10  20.15  28.15
# Rio Grande do Norte  15.40  21.35  31.60
# Rio Grande do Sul    11.35  19.35  21.95
# Rio de Janeiro       13.30  23.35  25.70
# Rondônia             15.80  20.85  26.70
# Roraima              14.50  20.75  22.65
# Santa Catarina       12.90  22.80  26.25
# Sergipe              14.70  21.45  26.80
# Sudeste              13.10  23.70  28.80
# Sul                  12.25  21.40  25.20
# São Paulo            14.65  25.15  28.70
# Tocantins            12.85  20.15  25.85

# %%
df.groupby("LOC")[["TI", "TF", "TM"]].median()
# Out:
#            TI    TF    TM
# LOC
# Rural   12.45  15.1  22.0
# Total   15.30  22.2  27.9
# Urbana  15.80  24.4  28.7

# %%
df.groupby(["UG", "LOC"])[["TI", "TF", "TM"]].median()
# Out:
#                      TI     TF     TM
# UG        LOC
# Acre      Rural    9.90  13.90  11.70
#           Total   16.85  20.50  22.25
#           Urbana  20.90  25.35  32.60
# Alagoas   Rural   16.60  19.80  33.10
#           Total   15.35  23.85  32.45
# ...                 ...    ...    ...
# São Paulo Total   14.30  25.85  31.00
#           Urbana  15.45  25.95  31.15
# Tocantins Rural   12.00  12.40  14.70
#           Total   15.95  21.35  24.95
#           Urbana  16.35  23.80  26.75
#
# [99 rows x 3 columns]

# %%
pd.pivot_table(df, values="TF", index="UG", columns="DA", aggfunc="median")
# Out:
# DA                   Estadual  Federal  Municipal  Privada  Pública  Total
# UG
# Acre                     21.2     25.0       18.7     20.8     20.2   20.2
# Alagoas                  29.6      0.0       24.5     17.5     25.0   23.2
# Amapá                    21.5      0.0       20.1     17.1     20.9   20.5
# Amazonas                 28.3     29.5       20.3     17.6     22.2   21.8
# Bahia                    28.5     26.2       21.3     17.2     21.6   20.6
# Brasil                   26.1     26.0       22.4     19.0     23.3   22.4
# Ceará                    17.7     28.9       23.6     18.1     23.5   22.1
# Centro-Oeste             26.0     30.3       23.6     19.0     24.6   23.4
# Distrito Federal         22.9     31.5        NaN     20.6     22.9   22.2
# Espírito Santo           26.7      0.0       22.6     21.6     23.2   23.0
# Goiás                    30.6     26.4       24.0     18.8     25.8   24.1
# Maranhão                 21.9     19.4       20.5     17.9     20.5   20.1
# Mato Grosso              25.1      0.0       22.2     18.4     23.3   22.5
# Mato Grosso do Sul       28.9     31.3       24.7     18.0     25.7   24.3
# Minas Gerais             24.7     22.6       20.1     19.7     21.9   21.5
# Nordeste                 26.7     24.5       22.0     17.9     22.4   21.3
# Norte                    24.3     26.1       20.9     18.6     21.7   21.4
# Paraná                   26.6     29.3       22.0     19.6     23.8   23.1
# Paraíba                  23.3     17.0       21.7     17.7     21.9   20.8
# Pará                     25.4     25.4       21.3     18.5     21.7   21.4
# Pernambuco               30.0     28.2       23.8     18.5     24.5   22.7
# Piauí                    26.2      0.0       20.6     19.7     20.9   20.7
# Rio Grande do Norte      24.9     21.6       21.9     17.5     22.5   21.1
# Rio Grande do Sul        19.1     29.1       19.0     22.9     19.1   19.6
# Rio de Janeiro           28.9     26.0       25.7     18.4     26.1   23.2
# Rondônia                 24.2      0.0       21.2     20.5     22.5   22.2
# Roraima                  20.6     24.3       21.4     20.0     21.0   20.9
# Santa Catarina           23.6     24.0       22.8     21.1     23.1   22.8
# Sergipe                  26.0     29.5       21.6     18.1     22.6   21.3
# Sudeste                  28.2     25.3       23.7     19.4     25.2   23.7
# Sul                      23.0     27.5       21.0     21.1     21.8   21.7
# São Paulo                30.1     26.5       25.2     19.8     27.1   25.1
# Tocantins                23.5      0.0       21.1     19.2     21.9   21.6

# %% [markdown]
# # Visualização de dados

# %%
import matplotlib.pyplot as plt
 
df.groupby("DA")[["TI", "TF", "TM"]].median().plot(kind="barh", figsize=(10, 5))
plt.title("Média de alunos por Dependência Administrativa")
plt.xlabel("Quantidade média de matrículas")
plt.ylabel("Tipo de administração")
plt.tight_layout()
plt.show()

# %%
df.groupby("LOC")[["TI", "TF", "TM"]].median().plot(kind="bar", figsize=(8, 5))
plt.title("Média de matrículas por Localização")
plt.ylabel("Média de alunos")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df.groupby("DA")["TI"].mean().plot.pie(autopct="%1.1f%%", figsize=(6, 6), ylabel="")
plt.title("Distribuição da Dependência Administrativa para o total Infantil")
plt.show()

# %% [markdown]
# # Passando meus dados analisados para csv

# %%
df.to_csv("atu-modi.csv", sep=';', decimal=',')
